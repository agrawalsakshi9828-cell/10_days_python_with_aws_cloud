# %% [markdown]
# # python basics and datatypes

# %%
print ("HELLO ALL ")
# Out:
# HELLO ALL

# %%
name = "sakii "

# %%
print(name)
# Out:
# sakii

# %%
type(name)
# Out:
# str

# %%
EXP = 7

# %%
print(EXP)
# Out:
# 7

# %%
type (EXP)
# Out:
# int

# %%
percentage = 88.66

# %%
type(percentage)
# Out:
# float

# %%
present = True

# %%
type(present)
# Out:
# bool

# %%
input()
# Out:
#  hhhhhhhhhhiiiiiiiiii
# 'hhhhhhhhhhiiiiiiiiii'

# %%
name  = input("Enter your name :")
# Out:
# Enter your name : sakiii

# %%
print(name)
# Out:
# sakiii

# %%
type(name)
# Out:
# str

# %%
age = int(input ("Enter Your AGE :"))
# Out:
# Enter Your AGE : 19

# %%
type(age)
# Out:
# int

# %%
print("Loading ", end="/")
print(".", end="/")
# Out:
# Loading /./

# %%
print("A" , "B " , "C")
# Out:
# A B  C

# %%
# Hi all how are you 

"""

Hi 
Guys 
hope 
you 
all 
are 
fine 




"""
# Out:
# '\n\nHi \nGuys \nhope \nyou \nall \nare \nfine \n\n\n\n\n'

# %% [markdown]
# # arithematic operator

# %%
a = 10

# %%
b = 20

# %%
print(a + b )
# Out:
# 30

# %%
print(b - a)
# Out:
# 10

# %%
print( a * b )
# Out:
# 200

# %%
print(a /b )
# Out:
# 0.5

# %%
print(a % b )
# Out:
# 10

# %%
a = 5
b = 2 
print(a ** b )
# Out:
# 25

# %% [markdown]
# # assignment operator

# %%
X = 10

# %%
print(X)
# Out:
# 10

# %%
X += 5

# %%
print(X)
# Out:
# 15

# %%
y = 20

# %%
y -= 10

# %%
print(y)
# Out:
# 10

# %% [markdown]
# # comparison operator

# %%
a = 10

# %%
b = 20

# %%
print (a == b)
# Out:
# False

# %%
print (a > b )
# Out:
# False

# %%
print(b > a)
# Out:
# True

# %%
print (a >= b )
# Out:
# False

# %%
print (a <= b)
# Out:
# True

# %%
print (a != b )
# Out:
# True

# %% [markdown]
# # logical operator

# %%
age = 20

# %%
movie_ticket = False

# %%
print(age > 18 and movie_ticket )
# Out:
# False

# %%
print( age > 18 or movie_ticket)
# Out:
# True

# %% [markdown]
# # membership operator

# %%
fruits = "apple"

# %%
print ("a" in fruits)
# Out:
# True

# %%
print("x" not in fruits)
# Out:
# True

# %% [markdown]
# # identity operator

# %%
a = [1 , 2 ,3]

# %%
b = a

# %%
print(b)
# Out:
# [1, 2, 3]

# %%
c = [1 , 2 ,3]

# %%
print (a is b )
# Out:
# True

# %%
print (a is c )
# Out:
# False

# %%
print( a == c)
# Out:
# True

# %% [markdown]
# # bitwise operator

# %%
a = 5

# %%
b = 3

# %%
print(a & b )
# Out:
# 1

# %%
print (a | b )
# Out:
# 7

# %%
print(a ^ b)
# Out:
# 6

# %% [markdown]
# # string operations

# %%
text = "Welcome to Linux World Family From Jibbran Ali "

# %%
print (len(text))
# Out:
# 47

# %%
print(   text.upper()  )
# Out:
# WELCOME TO LINUX WORLD FAMILY FROM JIBBRAN ALI

# %%
print ( text.title() )
# Out:
# Welcome To Linux World Family From Jibbran Ali

# %%
print( text.strip() )
# Out:
# Welcome to Linux World Family From Jibbran Ali

# %%
print (text.replace("Jibbran Ali" , "LW FAMILY "))
# Out:
# Welcome to Linux World Family From LW FAMILY

# %%
print(text.count("o"))
# Out:
# 4

# %%
print(text.find("Linux"))
# Out:
# 11

# %% [markdown]
# # slicing

# %%
WORD = "PYTHON"

# %%
print( WORD[0])
# Out:
# P

# %%
print( WORD[1])
# Out:
# Y

# %%
print( WORD[-1])
# Out:
# N

# %%
print( WORD[0:2])
# Out:
# PY

# %%
print( WORD[2:])
# Out:
# THON

# %% [markdown]
# # f string

# %%
name = "JACk"
age = 20

# %%
print ( "The name of student is name")
# Out:
# The name of student is name

# %%
print ( f"The name of student is {name} . The age of student is {age}")
# Out:
# The name of student is JACk . The age of student is 20

# %%
Exp = 7
name = str("Jibbran")

# %%
a  = "hello"

# %%
b = "World"

# %%
a + b
# Out:
# 'helloWorld'

# %%
a + " " + b
# Out:
# 'hello World'

# %%
print ("MY name is " , name)
# Out:
# MY name is  Jibbran
